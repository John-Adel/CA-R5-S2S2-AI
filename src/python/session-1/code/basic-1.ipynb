# %%
x = 4
print(x)
# Out:
# 4

# %% [markdown]
# print() always returns "none" that means we don't know the return value

# %% [markdown]
# format() returns "str"

# %%
print("my name is {}, my age is {}".format("John", 22))
'''
usually the index is ordered sequentially, but we can change the index 
'''
print("my name is {1}, my age is {0}".format("John", 22))
# Out:
# my name is John, my age is 22
# my name is 22, my age is John

# %%
name = "John"
age = 22
print(f"my name is {name}, my age is {age}")
# Out:
# my name is John, my age is 22

# %%
print("my", "name", sep=",")
# Out:
# my,name

# %%
a = 4
b = 5.5
c = "str"
d = True
e = [1, 2, 3, 4, "str", True, 1]
f = (1, 2, 3, 4, "str", False, 1)
g = {1, 2, 3, 4, "str", True, 1}
h = {"key1":"str", "key2":"value"}
print(a, type(a), b, type(b), c, type(c), d, type(d), e, type(e), f, type(f), g, type(g), h, type(h), sep = "\n")
# Out:
# 4
# <class 'int'>
# 5.5
# <class 'float'>
# str
# <class 'str'>
# True
# <class 'bool'>
# [1, 2, 3, 4, 'str', True, 1]
# <class 'list'>
# (1, 2, 3, 4, 'str', False, 1)
# <class 'tuple'>
# {1, 2, 3, 4, 'str'}
# <class 'set'>
# {'key1': 'str', 'key2': 'value'}
# <class 'dict'>

# %%
name = "Depi for machine learning"
print(type(name))
print(name[3])
print(name[-3])
print(name[4:8:1])
# Out:
# <class 'str'>
# i
# i
#  for

# %%
name = "depi for ml"
capital = name.upper()
print(capital)
print(capital.lower())
# Out:
# DEPI FOR ML
# depi for ml

# %%
name = "depi for everyone"
print(name.replace("depi", "amit"))
# Out:
# amit for everyone

# %%
print(name.capitalize())
print(name.title())
# Out:
# Depi for everyone
# Depi For Everyone

# %%
name = "depi learning for everyone"
print(name.count("n"))
# Out:
# 3

# %%
print(name.split())
# Out:
# ['depi', 'learning', 'for', 'everyone']

# %%
tokens = ["my", "name", "is", "John"]
sentence = " ".join(tokens)
print(sentence)
# Out:
# my name is John

# %%
name.startswith("depi")
# Out:
# True

# %% [markdown]
# # Escape Characters

# %%
print("Welcome \n to depi")
print("This is \"Depi\" Deploma")
print("Hello\tWorld!")
print("Hello\bWorld!")
# Out:
# Welcome
#  to depi
# This is "Depi" Deploma
# Hello	World!
# HellWorld!

# %%
stri = "0123456789"
print(stri[-2:-6:-2])
# Out:
# 86
