# %%
x = 10
print(type(x))
# Out:
# <class 'int'>

# %%
list_1 = [1, 2, 3, 4, "Depi", "learning", True, [1, 2, 3, ["ML", "AI", "GenAI"]]]
list_1[-1][-1][1]
# Out:
# 'AI'

# %%
x = "john"
list(x)
# Out:
# ['j', 'o', 'h', 'n']

# %%
list_1 = ["Depi", "learning", "ml"]
list_1.append("GenAi")

# %%
list_1
# Out:
# ['Depi', 'learning', 'ml', 'GenAi']

# %%
list_1 = ["Depi", "learning", "ml"]
list_1.insert(1, "Deep learning")
list_1
# Out:
# ['Depi', 'Deep learning', 'learning', 'ml']

# %%
list_1 = ["Depi", "learning", "ml"]
list_2 = ["NTI", "learning", "GenAi"]
x = list_1 + list_2
print(x)
list_1.extend(list_2)
list_1
# Out:
# ['Depi', 'learning', 'ml', 'NTI', 'learning', 'GenAi']
# ['Depi', 'learning', 'ml', 'NTI', 'learning', 'GenAi']

# %%
list_1 = ["Depi", "learning", "ml", "learning"]
list_1.remove("learning")
list_1
# Out:
# ['Depi', 'ml', 'learning']

# %%
list_1 = ["Depi", "learning", "ml"]
x = list_1.pop()
print(x)
print(type(x))
# Out:
# ml
# <class 'str'>

# %%
list_1 = ["Depi", "learning", "ml"]
del list_1[0]
list_1
# Out:
# ['learning', 'ml']

# %%
name = input("enter your name")
id = input("enter your id")
print(name, id)

# %%
list_1 = ["Depi", "learning", "ml", "learning"]
item = input("Enter item: ")
list_1.remove(item)

# %%
list_1 = ["Depi", "learning", "ml", "learning"]
list_1.index("Depi")
list_1.count("Depi")
# Out:
# 1

# %%
list_1 = [30, 10, 5, 18, 20]
x = list_1.sort()
print(x)
print(list_1)
# Out:
# None
# [5, 10, 18, 20, 30]

# %%
list_2 = [30, 10, 5, 18, 35]
x = sorted(list_2)
print(list_2)
print(x)
# Out:
# [30, 10, 5, 18, 35]
# [5, 10, 18, 30, 35]

# %%
list_3 = [1, 2, 3]
list_3.reverse()

# %%
list_3
# Out:
# [3, 2, 1]

# %%
tup = ("Depi", "learning", "ml", "learning")
tup[2]
# Out:
# 'ml'

# %%
lst = list(tup)
lst.remove("ml")
tup = tuple(lst)

# %%
tup
# Out:
# ('Depi', 'learning', 'learning')

# %%
set1 = {1, 2, 3}
set2 = {3, 4, 5}
print(set1|set2) #union
print(set1.intersection(set2))
print(set1.difference(set2))
print(set1.union(set2))
# Out:
# {1, 2, 3, 4, 5}
# {3}
# {1, 2}
# {1, 2, 3, 4, 5}

# %%
dic = {"k1" : 10.5, "k2" : "Depi", "k3" : "python", 20 : [1, 2, 3, 4, 5]}
dic.keys()
dic["k1"] = "ai engineer"
dic
# Out:
# {'k1': 'ai engineer', 'k2': 'Depi', 'k3': 'python', 20: [1, 2, 3, 4, 5]}

# %%
lst_of_tup = [('a', 1), ('b', 2), ('c', 3)]
dic = dict(lst_of_tup)
print(dic)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
num = float(input("enter the first num"))
num2 = float(input("enter the second num"))

print(f"first num {num} + second num {num2} = ", num + num2)
print(f"first num {num} - second num {num2} = ", num - num2)
print(f"first num {num} / second num {num2} = ", num / num2)
print(f"first num {num} * second num {num2} = ", num * num2)
# Out:
# first num 10.0 + second num 20.0 =  30.0
# first num 10.0 - second num 20.0 =  -10.0
# first num 10.0 / second num 20.0 =  0.5
# first num 10.0 * second num 20.0 =  200.0

# %%
a = 200
b = 33
if b > a:
    print("b is greater than a")
else:
    print("b is not greater than a")
# Out:
# b is not greater than a

# %%
x = 5
result = "even" if x % 2 == 0 else "odd"

# %%
a = 10
b = 5
result = a + b if a > b else a - b

# %%
is_sunny = True
temperature = 25

if is_sunny:
    print("It's a sunny day!")

    if temperature > 20:
        print("the weather is warm")
    else:
        print("the weather is cool")
else:
    print("It's not sunny day.")
# Out:
# It's a sunny day!
# the weather is warm

# %%
grade = int(input("Enter your grade: "))
if grade >= 90 or grade <= 100:
    print('A')
elif grade >= 80 or grade < 90:
    print('B')
elif grade >= 70 or grade < 80:
    print('C')
# Out:
# A

# %%
for i in "depi":
    print(i)
# Out:
# d
# e
# p
# i

# %%
for i in range(6):
    if i == 3:
        continue
    print(i, end = "")
# Out:
# 01245

# %%
for i in range(6):
    if i == 3:
        break
    print(i)
# Out:
# 0
# 1
# 2

# %%
for i in range(6):
    if i == 3:
        pass
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(6):
    if i == 3:
        ...
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
