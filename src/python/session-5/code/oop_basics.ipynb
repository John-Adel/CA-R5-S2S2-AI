# %%
class Student:
    name = "George"
    age = 39

    def std_info():
        print("Welcome depi students")

# %%
s1 = Student()
s1.name = "depi"
print(s1.name)

# %%
class Student:
    def __init__(self, name, age):
        self.name = name
        self.age = age
    def std_info(self):
        return f"My name is {self.name}, I am {self.age} years old"

# %%
s1 = Student("John", 39)
print(s1.name)
print(s1.age)
s1.std_info()
# Out:
# John
# 39
# 'My name is John, I am 39 years old'

# %%
'''  

'''


class Calc:
    def __init__(self, x:int, y:int) -> None:
        self.x = x
        self.y = y

    def add(self):
        return self.x + self.y

    def sub(self):
        return self.x - self.y

# %%
c1 = Calc(20, 30)
print("x:", c1.x, "\ny:", c1.y)
print("addition =", c1.add(), "\nsubtration =", c1.sub())
# Out:
# x: 20
# y: 30
# addition = 50
# subtration = -10

# %%
from abc import ABC, abstractmethod

class Animal(ABC):

    @abstractmethod
    def move(self):
        pass

class Bird(Animal):

    def move(self):
        print("move from bird")

class Cat(Animal):

    def move(self):
        print("move from cat")

class Dog(Cat):
    pass

# %%
a = Bird()
a.move()
d = Dog()
d.move()
# Out:
# move from bird
# move from cat

# %%
class Rectangle:
    _length = 5
    __width = 10
    example = 0

    def area(self):
        return self._length * self.__width

r = Rectangle()
print(r._length)
print(r._Rectangle__width)
print(r.area())
# Out:
# 5
# 10
# 50

# %%
class parent:
    def __init__(self) -> None:
        self.__value = 10 

class child(parent):
    def __init__(self):
        super().__init__()
        self.__value = 20

# %%
c = child()
print(c.__dict__)
# Out:
# {'_parent__value': 10, '_child__value': 20}

# %%
#This is duck test or override
class Dog:
    def speak(self):
        return "woof"

class Cat:
    def speak(self):
        return "meow"

def make_sound(animal):
    return animal.speak()
dog = Dog()
cat = Cat()
print(make_sound(dog))
print(make_sound(cat))
# Out:
# woof
# meow

# %%
class Calc:
    def add(self, a):
        return a
    def add(self, a, b):
        return a + b

# %%
class A():
    def do_this(self):
        print("I am in A")

class B(A):
    pass

class C():
    def do_this(self):
        print("I am in C")

class D(B, C):
    pass

x = D()
x.do_this()
# Out:
# I am in A

# %%
class A():
    def do_this(self):
        print("I am in A")

class B(A):
    pass

class C():
    def do_this(self):
        print("I am in C")

class D(C, B):
    pass

x = D()
x.do_this()
# Out:
# I am in C

# %%
class Student:
    def __init__(self, name, age) -> None:
        self.name = name
        self.age = age

    def __str__(self) -> str: #for the user
        return f"my name is {self.name}, my age is {self.age}"

    def __repr__(self) -> str: #for the developer
        return f"my name is {self.name}, my age is {self.age}"

# %%
s1 = Student("depi", 20)
str(s1)
# Out:
# 'my name is depi, my age is 20'

# %%
def
